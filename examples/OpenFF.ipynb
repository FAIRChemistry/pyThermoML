# %% [markdown]
# # Test your ThermoML.xml file!
#
# Test your ThermoML.xml file with openff.

# %%
from openff.evaluator.datasets.thermoml import ThermoMLDataSet

# %% [markdown]
# Read thermoml data set

# %%
dataset = ThermoMLDataSet.from_file("files/test.xml")

dataset
# Out:
# <PhysicalPropertyDataSet n_properties=26 n_substances=19 n_sources=1>

# %% [markdown]
# Convert the read data set in a pandas data frame for display

# %%
dataset.to_pandas()
# Out:
#                                   Id  Temperature (K)  Pressure (kPa)   Phase  \
# 0   93ffb1af40514a22b8c12e648ed4b8ff           313.15           100.0  Liquid
# 1   c814ef711903473e8496599e58730ea1           323.15           100.0  Liquid
# 2   950b7b9ae8e24ec0b9fa87eef62a356f           333.15           100.0  Liquid
# 3   eab04024cbe149d5a10e4c0710aaf7e9           343.15           100.0  Liquid
# 4   0c514b6195914451bcc7320450965b7d           353.15           100.0  Liquid
# 5   8109ca549c3c4d8683681b64dcd9de56           298.15           100.0  Liquid
# 6   5ce3901d8b7143cd87ba57d0f59e8efd           308.15           100.0  Liquid
# 7   10335acf5c3e4daa9dbde2a817748dc0           308.15           100.0  Liquid
# 8   921338c6118c4df3b2e510ed54335307           298.15           100.0  Liquid
# 9   12d14118f8dd44da96fbf3c4e30708ad           308.15           100.0  Liquid
# 10  77a5fff3887a4b209abab7e3ed9694d8           298.15           100.0  Liquid
# ...

# %%
dataset.substances
# Out:
# {<Substance C[N+](C)(C)CCO{solv}{x=0.006000}|OCC(O)CO{solv}{x=0.025000}|O{solv}{x=0.961800}|[Cl-]{solv}{x=0.007200}>,
#  <Substance C[N+](C)(C)CCO{solv}{x=0.007000}|OCC(O)CO{solv}{x=0.028000}|O{solv}{x=0.958200}|[Cl-]{solv}{x=0.006800}>,
#  <Substance C[N+](C)(C)CCO{solv}{x=0.008000}|OCC(O)CO{solv}{x=0.034000}|O{solv}{x=0.949700}|[Cl-]{solv}{x=0.008300}>,
#  <Substance C[N+](C)(C)CCO{solv}{x=0.013000}|OCC(O)CO{solv}{x=0.053000}|O{solv}{x=0.920300}|[Cl-]{solv}{x=0.013700}>,
#  <Substance C[N+](C)(C)CCO{solv}{x=0.023000}|OCC(O)CO{solv}{x=0.091000}|O{solv}{x=0.864200}|[Cl-]{solv}{x=0.021800}>,
#  <Substance C[N+](C)(C)CCO{solv}{x=0.025000}|OCC(O)CO{solv}{x=0.098000}|O{solv}{x=0.852400}|[Cl-]{solv}{x=0.024600}>,
#  <Substance C[N+](C)(C)CCO{solv}{x=0.032000}|OCC(O)CO{solv}{x=0.127000}|O{solv}{x=0.809300}|[Cl-]{solv}{x=0.031700}>,
#  <Substance C[N+](C)(C)CCO{solv}{x=0.034000}|OCC(O)CO{solv}{x=0.137000}|O{solv}{x=0.794800}|[Cl-]{solv}{x=0.034200}>,
# ...
